# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('D:/shree/customer_retention.csv')

# %%
df.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %%
df.tail()
# Out:
#     1Gender of respondent 2 How old are you?   \
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 264                                 Solan
# 265                             Ghaziabad
# 266                            Bangalore
# 267                                 Solan
# 268                             Ghaziabad
#
#      4 What is the Pin Code of where you shop online from?  \
# 264                                             173212
# 265                                             201008
# 266                                             560010
# 267                                             173229
# 268                                             201009
#
#     5 Since How Long You are Shopping Online ?  \
# ...

# %%
df.shape
# Out:
# (269, 71)

# %%
df.dtypes
# Out:
# 1Gender of respondent                                                   object
# 2 How old are you?                                                      object
# 3 Which city do you shop online from?                                   object
# 4 What is the Pin Code of where you shop online from?                    int64
# 5 Since How Long You are Shopping Online ?                              object
#                                                                          ...
# Longer delivery period                                                  object
# Change in website/Application design                                    object
# Frequent disruption when moving from one page to another                object
# Website is as efficient as before                                       object
# Which of the Indian online retailer would you recommend to a friend?    object
# Length: 71, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                          --------------  -----
#  0   1Gender of respondent                                                                                                                                                                                           269 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# 1Gender of respondent                                                   0
# 2 How old are you?                                                      0
# 3 Which city do you shop online from?                                   0
# 4 What is the Pin Code of where you shop online from?                   0
# 5 Since How Long You are Shopping Online ?                              0
#                                                                        ..
# Longer delivery period                                                  0
# Change in website/Application design                                    0
# Frequent disruption when moving from one page to another                0
# Website is as efficient as before                                       0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
df['1Gender of respondent']. value_counts()
# Out:
# Female    181
# Male       88
# Name: 1Gender of respondent, dtype: int64

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
df.cols=['V1','V2','V3','V4','V5','V6','V7', 'V8','V9','V10','V11','V12','V13','V14','V15','V16', 'V17',
       '18 The content on the website must be easy to read and understand',
       '19 Information on similar product to the one highlighted  is important for product comparison',
       '20 Complete information on listed seller and product being offered is important for purchase decision.',
       '21 All relevant information on listed products must be stated clearly',
       '22 Ease of navigation in website', '23 Loading and processing speed',
       '24 User friendly Interface of the website',
       '25 Convenient Payment methods',
       '26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time',
       '27 Empathy (readiness to assist with queries) towards the customers',
       '28 Being able to guarantee the privacy of the customer',
       '29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)',
       '30 Online shopping gives monetary benefit and discounts',
       '31 Enjoyment is derived from shopping online',
       '32 Shopping online is convenient and flexible',
       '33 Return and replacement policy of the e-tailer is important for purchase decision',
       '34 Gaining access to loyalty programs is a benefit of shopping online',
       '35 Displaying quality Information on the website improves satisfaction of customers',
       '36 User derive satisfaction while shopping on a good quality website or application',
       '37 Net Benefit derived from shopping online can lead to users satisfaction',
       '38 User satisfaction cannot exist without trust',
       '39 Offering a wide variety of listed product in several category',
       '40 Provision of complete and relevant product information',
       '41 Monetary savings',
       '42 The Convenience of patronizing the online retailer',
       '43 Shopping on the website gives you the sense of adventure',
       '44 Shopping on your preferred e-tailer enhances your social status',
       '45 You feel gratification shopping on your favorite e-tailer',
       '46 Shopping on the website helps you fulfill certain roles',
       '47 Getting value for money spent',
       'From the following, tick any (or all) of the online retailers you have shopped from;                                                                           ',
       'Easy to use website or application',
       'Visual appealing web-page layout', 'Wild variety of product on offer',
       'Complete, relevant description information of products',
       'Fast loading website speed of website and application',
       'Reliability of the website or application',
       'Quickness to complete purchase',
       'Availability of several payment options', 'Speedy order delivery ',
       'Privacy of customers? information',
       'Security of customer financial information',
       'Perceived Trustworthiness',
       'Presence of online assistance through multi-channel',
       'Longer time to get logged in (promotion, sales period)',
       'Longer time in displaying graphics and photos (promotion, sales period)',
       'Late declaration of price (promotion, sales period)',
       'Longer page loading time (promotion, sales period)',
       'Limited mode of payment on most products (promotion, sales period)',
       'Longer delivery period', 'Change in website/Application design',
       'Frequent disruption when moving from one page to another',
       'Website is as efficient as before',
       'Which of the Indian online retailer would you recommend to a friend?']

# %%
df.columns=df.cols

# %%
df.head()
# Out:
#        V1           V2             V3      V4             V5  \
# 0    Male  31-40 years          Delhi  110009  Above 4 years
# 1  Female  21-30 years          Delhi  110030  Above 4 years
# 2  Female  21-30 years  Greater Noida  201308      3-4 years
# 3    Male  21-30 years        Karnal   132001      3-4 years
# 4  Female  21-30 years     Bangalore   530068      2-3 years
#
#                    V6               V7          V8          V9  \
# 0         31-40 times          Dial-up     Desktop      Others
# 1  41 times and above            Wi-Fi  Smartphone  4.7 inches
# 2  41 times and above  Mobile Internet  Smartphone  5.5 inches
# 3  Less than 10 times  Mobile Internet  Smartphone  5.5 inches
# 4         11-20 times            Wi-Fi  Smartphone  4.7 inches
#
#                      V10  ...  \
# 0  Window/windows Mobile  ...
# 1                IOS/Mac  ...
# 2                Android  ...
# 3                IOS/Mac  ...
# 4                IOS/Mac  ...
#
# ...

# %% [markdown]
# # UNIVARIATE ANALYSIS & VISUALIZATION

# %% [markdown]
# # V1 = Gender of respondent

# %%
df['V1']. value_counts()
# Out:
# Female    181
# Male       88
# Name: V1, dtype: int64

# %%
df.V1.value_counts().sort_values().plot(kind = 'barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # V2 = How old are you?

# %%
df['V2']. value_counts()
# Out:
# 31-40 years           81
# 21-30 years           79
# 41-50 yaers           70
# Less than 20 years    20
# 51 years and above    19
# Name: V2, dtype: int64

# %%
df.V2.value_counts().sort_values().plot(kind = 'barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # V3 = Which city do you shop online from?

# %%
df['V3']. value_counts()
# Out:
# Delhi            58
# Greater Noida    43
# Noida            40
# Bangalore        37
# Karnal           27
# Solan            18
# Ghaziabad        18
# Gurgaon          12
# Merrut            9
# Moradabad         5
# Bulandshahr       2
# Name: V3, dtype: int64

# %%
df.replace({'V3':{'Noida':' Greater Noida'}},inplace=True)

# %%
df.V3.value_counts().sort_values().plot(kind = 'barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # V5 =  Since How Long You are Shopping Online ?

# %%
df['V5']. value_counts()
# Out:
# Above 4 years       98
# 2-3 years           65
# 3-4 years           47
# Less than 1 year    43
# 1-2 years           16
# Name: V5, dtype: int64

# %%
df.V5.value_counts().sort_values().plot(kind = 'barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # V6 =  How many times you have made an online purchase in the past 1 year?

# %%
df['V6']. value_counts()
# Out:
# Less than 10 times    114
# 31-40 times            63
# 41 times and above     47
# 11-20 times            29
# 21-30 times            10
# 42 times and above      6
# Name: V6, dtype: int64

# %%
df.replace({'V6':{'42 times and above':'41 times and above'}},inplace=True)

# %%
df['V6']. value_counts()
# Out:
# Less than 10 times    114
# 31-40 times            63
# 41 times and above     53
# 11-20 times            29
# 21-30 times            10
# Name: V6, dtype: int64

# %%
df.V6.value_counts().sort_values().plot(kind = 'barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # V7 =  How do you access the internet while shopping on-line?

# %%
df['V7']. value_counts()
# Out:
# Mobile internet    142
# Wi-Fi               76
# Mobile Internet     47
# Dial-up              4
# Name: V7, dtype: int64

# %% [markdown]
# # We can see here that there is need to be clean the data, as Mobile Internet data has been filled differently .

# %%
df.replace({'V7':{'Mobile internet':'Mobile Internet'}},inplace=True)

# %%
df['V7']. value_counts()
# Out:
# Mobile Internet    189
# Wi-Fi               76
# Dial-up              4
# Name: V7, dtype: int64

# %%
df.V7.value_counts().sort_values().plot(kind = 'barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # V8 = Which device do you use to access the online shopping?

# %%
df['V8']. value_counts()
# Out:
# Smartphone    141
# Laptop         86
# Desktop        30
# Tablet         12
# Name: V8, dtype: int64

# %%
plt.figure(figsize=(6,6))
sns.countplot(x='V8',data =df)
plt.show()

# %% [markdown]
# # V9 = What is the screen size of your mobile device?

# %%
df['V9']. value_counts()
# Out:
# Others        134
# 5.5 inches     99
# 4.7 inches     29
# 5 inches        7
# Name: V9, dtype: int64

# %%
plt.figure(figsize=(6,6))
sns.countplot(x='V9',data =df)
plt.show()

# %% [markdown]
# # V10 = What is the operating system (OS) of your device?

# %%
df['V10']. value_counts()
# Out:
# Window/windows Mobile    122
# Android                   85
# IOS/Mac                   62
# Name: V10, dtype: int64

# %%
plt.figure(figsize=(6,6))
sns.countplot(x='V10',data =df)
plt.show()

# %% [markdown]
# # V11 = What browser do you run on your device to access the website?

# %%
df['V11']. value_counts()
# Out:
# Google chrome      216
# Safari              40
# Opera                8
# Mozilla Firefox      5
# Name: V11, dtype: int64

# %%
plt.figure(figsize=(6,6))
sns.countplot(x='V11',data =df)
plt.show()

# %% [markdown]
# # V12 = Which channel did you follow to arrive at your favorite online store for the first time?

# %%
df['V12']. value_counts()
# Out:
# Search Engine        230
# Content Marketing     20
# Display Adverts       19
# Name: V12, dtype: int64

# %%
plt.figure(figsize=(6,6))
sns.countplot(x='V12',data =df)
plt.show()

# %% [markdown]
# # V13 =  After first visit, how do you reach the online retail store?

# %%
df['V13']. value_counts()
# Out:
# Search Engine      87
# Via application    86
# Direct URL         70
# E-mail             18
# Social Media        8
# Name: V13, dtype: int64

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='V13',data =df)
plt.show()

# %% [markdown]
# # V14 =  How much time do you explore the e- retail store before making a purchase decision?

# %%
df['V14']. value_counts()
# Out:
# more than 15 mins    123
# 6-10 mins             71
# 11-15 mins            46
# Less than 1 min       15
# 1-5 mins              14
# Name: V14, dtype: int64

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='V14',data =df)
plt.show()

# %% [markdown]
# # V15 = What is your preferred payment Option?

# %%
df['V15']. value_counts()
# Out:
# Credit/Debit cards                    148
# Cash on delivery (CoD)                 76
# E-wallets (Paytm, Freecharge etc.)     45
# Name: V15, dtype: int64

# %%
plt.figure(figsize=(9,5))
sns.countplot(x='V15',data =df)
plt.show()

# %% [markdown]
# # V16 = How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?

# %%
df['V16']. value_counts()
# Out:
# Sometimes          171
# Never               48
# Frequently          35
# Very frequently     15
# Name: V16, dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='V16',data =df)
plt.show()

# %% [markdown]
# # V17 = Why did you abandon the ?Bag?, ?Shopping Cart?

# %%
df['V17']. value_counts()
# Out:
# Better alternative offer        133
# Promo code not applicable        54
# Change in price                  37
# Lack of trust                    31
# No preferred mode of payment     14
# Name: V17, dtype: int64

# %%
plt.figure(figsize=(12,5))
sns.countplot(x='V17',data =df)
plt.show()

# %%
df["V1"] = [1 if i == "Female" else 0 for i in df["V1"]]

# %%
df["V1"].head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    0
# 4    1
# Name: V1, dtype: int64

# %%
def tran_V2(x):
    if x == 'Less than 20 years':
        return 1
    if x == '21-30 years':
        return 2
    if x == '31-40 years':
        return 3
    if x == '41-50 yaers':
        return 4
    if x == '51 years and above':
        return 5
    
    
    
df['V2']=df['V2'].apply(tran_V2)

# %%
def tran_V5(x):
    if x == 'Less than 1 year':
        return 1
    if x == '1-2 years':
        return 2
    if x == '2-3 years':
        return 3
    if x == '3-4 years':
        return 4
    if x == 'Above 4 years':
        return 5
    
    
    
df['V5']=df['V5'].apply(tran_V5)

# %%
def tran_V6(x):
    if x == 'Less than 10 times':
        return 1
    if x == '11-20 times':
        return 2
    if x == '21-30 times':
        return 3
    if x == '31-40':
        return 4
    if x == '41 times and above':
        return 5
    
    
    
df['V6']=df['V6'].apply(tran_V6)

# %%
def tran_V7(x):
    if x == 'Mobile Internet ':
        return 1
    if x == 'Wi-Fi ':
        return 2
    if x == 'Dial-up':
         return 3

    
    
    
df['V7']=df['V7'].apply(tran_V7)

# %%
def tran_V8(x):
    if x == 'Smartphone':
        return 1
    if x == 'Laptop':
        return 2
    if x == 'Desktop':
        return 3
    if x == 'Tablet':
        return 4
    
    
    
df['V8']=df['V8'].apply(tran_V8)

# %%
def tran_V9(x):
    if x == '4.7 inches':
        return 1
    if x == '5 inches':
        return 2
    if x == '5.5 inches':
        return 3
    if x == 'Others':
        return 4
    
    
    
df['V9']=df['V9'].apply(tran_V9)

# %%
def tran_V10(x):
    if x == 'Window/windows Mobile':
        return 1
    if x == 'Android':
        return 2
    if x == 'IOS/Mac':
        return 3
    
    
    
df['V10']=df['V10'].apply(tran_V10)

# %%
def tran_V11(x):
    if x == 'Google chrome':
        return 1
    if x == 'Safari':
        return 2
    if x == 'Opera':
        return 3
    if x == 'Mozilla Firefox':
        return 4
    
    
    
df['V11']=df['V11'].apply(tran_V11)

# %%
def tran_V12(x):
    if x == 'Search Engine':
        return 1
    if x == 'Content Marketing':
        return 2
    if x == 'Display Adverts':
        return 3
    
df['V12']=df['V12'].apply(tran_V12)

# %%
def tran_V13(x):
    if x == 'Search Engine':
        return 1
    if x == 'Via application':
        return 2
    if x == 'Direct URL':
        return 3
    if x == 'E-mail':
        return 4
    if x == 'Social Media':
        return 5
    
    
df['V13']=df['V13'].apply(tran_V13)

# %%
def tran_V14(x):
    if x == 'Less than 1 min':
        return 1
    if x == '1-5 mins':
        return 2
    if x == '6-10 mins':
        return 3
    if x == '11-15 mins':
        return 4
    if x == 'more than 15 mins':
        return 4
    
    
df['V14']=df['V14'].apply(tran_V14)

# %%
def tran_V15(x):
    if x == 'Credit/Debit cards':
        return 1
    if x == 'Cash on delivery (CoD)':
        return 2
    if x == 'E-wallets (Paytm, Freecharge etc.)':
        return 3
    
    
df['V15']=df['V15'].apply(tran_V15)

# %%
def tran_V16(x):
    if x == 'Sometimes':
        return 1
    if x == 'Never':
        return 2
    if x == 'Frequently':
        return 3
    if x == 'Very frequently':
        return 4
    
    
    
df['V16']=df['V16'].apply(tran_V16)

# %%
def tran_V17(x):
    if x == 'Better alternative offer':
        return 1
    if x == 'Promo code not applicable':
        return 2
    if x == 'Change in price':
        return 3
    if x == 'Lack of trust':
        return 4
    if x == 'No preferred mode of payment':
        return 4
    
    
df['V17']=df['V17'].apply(tran_V17)

# %%
df.head()
# Out:
#    V1  V2             V3      V4  V5   V6   V7  V8  V9  V10  ...  \
# 0   0   3          Delhi  110009   5  NaN  3.0   3   4    1  ...
# 1   1   2          Delhi  110030   5  5.0  NaN   1   1    3  ...
# 2   1   2  Greater Noida  201308   4  5.0  NaN   1   3    2  ...
# 3   0   2        Karnal   132001   4  1.0  NaN   1   3    3  ...
# 4   1   2     Bangalore   530068   3  2.0  NaN   1   1    3  ...
#
#    Longer time to get logged in (promotion, sales period)  \
# 0                                          Amazon.in
# 1                            Amazon.in, Flipkart.com
# 2                                         Myntra.com
# 3                                       Snapdeal.com
# 4                            Flipkart.com, Paytm.com
#
#    Longer time in displaying graphics and photos (promotion, sales period)  \
# 0                                          Amazon.in
# 1                                         Myntra.com
# 2                                         Myntra.com
# ...

# %% [markdown]
# # BIVARIATE ANALYSIS AND VISUALIZATION

# %%
g = sns.factorplot(x = "V3", y = "V1", data = df, kind = "bar", size = 10)
g.set_ylabels("Male Female")
plt.show()

# %%
g = sns.factorplot(x = "V5", y = "V1", data = df, kind = "bar", size = 5)
g.set_ylabels("Male Female")
g.set_xlabels("Since How Long You are Shopping Online ?")
plt.show()

# %% [markdown]
# 1 = Less than 1 year
#
# 2 = 1-2 years
#
# 3 = 2-3 years
#
# 4 = 3-4 years
#
# 5 = Above 4 years

# %%
g = sns.factorplot(x = "V14", y = "V1", data = df, kind = "bar", size = 5)
g.set_ylabels("Male Female")
g.set_xlabels("How much time do you explore the e- retail store before making a purchase decision?")
plt.show()

# %% [markdown]
# 1 = Less than 1 min
#
# 2 =  1-5 mins
#
# 3 = 6-10 mins
#
# 4 = 11-15 mins
#
# 5 = more than 15 mins

# %%
g = sns.factorplot(x = "V16", y = "V1", data = df, kind = "bar", size = 5)
g.set_ylabels("Male Female")
g.set_xlabels("How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?")
plt.show()

# %% [markdown]
# 1 = Sometimes
#
# 2 = Never
#
# 3 = Frequently
#
# 4 = Very frequently

# %%
plt.figure(figsize=(10,8))
sns.countplot(df['V5'],hue=df['V1'])
# Out:
# <AxesSubplot:xlabel='V5', ylabel='count'>

# %% [markdown]
# Highest number of people have been shopping online for above 4 years except for the age group below 20 years and above 50 years. People who are shopping online for 1-2 years does not include teenagers and elder people.

# %%
plt.figure(figsize=(10,8))
sns.countplot(df['V5'],
              hue=df['V13'])
# Out:
# <AxesSubplot:xlabel='V5', ylabel='count'>

# %% [markdown]
# Even though people who are shopping online for more than 3 years donot use the application rather use search engine and direct url's in large number which indicates that online brands should update all their platforms rather than just application

# %%
performance=['Easy to use website or application',
       'Visual appealing web-page layout', 
        'Wild variety of product on offer',
       'Complete, relevant description information of products',
       'Fast loading website speed of website and application',
       'Reliability of the website or application',
       'Quickness to complete purchase',
       'Availability of several payment options',
       'Security of customer financial information',
       'Perceived Trustworthiness',
       'Presence of online assistance through multi-channel']

# %%
for i in performance:
        plt.figure(figsize=(8,6))
        df[i].value_counts().plot.pie(autopct='%1.1f%%')
        centre=plt.Circle((0,0),0.7,fc='white')
        fig=plt.gcf()
        fig.gca().add_artist(centre)
        plt.xlabel(i)
        plt.ylabel('')
        plt.figure()
        
import warnings
warnings.filterwarnings('ignore')

plt.savefig("pp1.png")

# %% [markdown]
# Amazon, Flipkart have been had the highest votes for having all the positive points and have maintained a very good brand image followed by paytm and the myntra.

# %%
#Collecting all the negative remarks about a brand
bad=['Longer time to get logged in (promotion, sales period)',
       'Longer time in displaying graphics and photos (promotion, sales period)',
       'Late declaration of price (promotion, sales period)',
       'Longer page loading time (promotion, sales period)',
       'Limited mode of payment on most products (promotion, sales period)',
       'Longer delivery period', 'Change in website/Application design',
       'Frequent disruption when moving from one page to another']

# %%
for i in bad:
        plt.figure(figsize=(15,6))
        sns.countplot(df[i],hue=df['Which of the Indian online retailer would you recommend to a friend?'])
        plt.xticks(rotation=45)
        plt.figure()

# %% [markdown]
# Customers seem to be more loyal to amazon, flipkart and paytm as even though many of them have given negative remarks about them still they would recommend these platforms to their friend
